# %%
# read a picture

import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

#reading the image 

image = cv2.imread('penquin.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
cv2.line(image,(0,0),(1000,600),(128, 128, 128),15)
cv2.circle(image,(100,63), 55, (0,255,0), 1) # - minus means full fill
px = image[55, 55]
image[55, 55] = [255, 255, 255]
px = image[55, 55]
# px = image[100:150,100:150]
image[100:500,100:500] = [0, 0, 0] # [startX:endY, startY:endY]

#plotting the image
plt.imshow(image)
# print(px)
print(image.shape)
print(image.size)
print(image.dtype)

#saving image
#cv2.imwrite('test_write.jpg',image)
# Out:
# (640, 1024, 3)
# 1966080
# uint8

# %%
# color space changing  

import numpy as np 
import matplotlib.pyplot as plt 
import cv2 
# %matplotlib inline 
image = cv2.imread('penquin.jpg') 
#converting image to Gray scale 
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#plotting the grayscale image
plt.imshow(gray_image) 
#converting image to HSV format
#hsv_image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
#plotting the HSV image
#plt.imshow(hsv_image)

# %%
# image resize

import cv2 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
#reading the image 
image = cv2.imread('penquin.jpg') 
#converting image to size (100,100,3) 
smaller_image_01 = cv2.resize(image,(100,100),interpolation=cv2.INTER_NEAREST) 
smaller_image_02 = cv2.resize(image,(100,100),interpolation=cv2.INTER_LINEAR)
smaller_image_03 = cv2.resize(image,(100,100),interpolation=cv2.INTER_AREA)
smaller_image_04 = cv2.resize(image,(100,100),interpolation=cv2.INTER_CUBIC)
smaller_image_05 = cv2.resize(image,(100,100),interpolation=cv2.INTER_LANCZOS4)

names = ['INTER_NEAREST','INTER_LINEAR','INTER_AREA','INTER_CUBIC','INTER_;ANCZ0S4']
images = smaller_image_01, smaller_image_02, smaller_image_03, smaller_image_04, smaller_image_05

for i in range(5):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

#plot the resized image
#plt.imshow(smaller_image_01)
#plt.imshow(smaller_image_02)
#plt.imshow(smaller_image_03)
#plt.imshow(smaller_image_04)
#plt.imshow(smaller_image_05)

# %%
# image rotation 

import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 
image = cv2.imread('penquin.jpg') 
rows,cols = image.shape[:2] 
#(col/2,rows/2) is the center of rotation for the image 
# M is the cordinates of the center 
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1) 
dst = cv2.warpAffine(image,M,(cols,rows)) 
plt.imshow(dst)

# %%
#Simple Image Thresholding

import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 

#here 0 means that the image is loaded in gray scale format
gray_image = cv2.imread('penquin.jpg',0)

ret,thresh_binary = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
ret,thresh_binary_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc = cv2.threshold(gray_image,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero = cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO)
ret,thresh_tozero_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO_INV)

#DISPLAYING THE DIFFERENT THRESHOLDING STYLES
names = ['Oiriginal Image','BINARY','THRESH_BINARY_INV','THRESH_TRUNC','THRESH_TOZERO','THRESH_TOZERO_INV']
images = gray_image,thresh_binary,thresh_binary_inv,thresh_trunc,thresh_tozero,thresh_tozero_inv

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %%
# edge detection

import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline
#read the image
image = cv2.imread('penquin.jpg') 
#calculate the edges using Canny edge algorithm
edges = cv2.Canny(image,100,200) 
#plot the edges
plt.imshow(edges)

# %%
import cv2
import matplotlib
import numpy

cap = cv2.VideoCapture(0)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("Image Size: %d x %d" % (width, height))

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 720)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)


while(True):
    ret, img = cap.read()
    cv2.imshow('frame',img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.imwrite('output.jpg', img)
        break

        cap.release()
cv2.destroyAllWindows()
# Out:
# Image Size: 0 x 0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-3d6709db520d> in <module>
#      14 while(True):
#      15     ret, img = cap.read()
# ---> 16     cv2.imshow('frame',img)
#      17     if cv2.waitKey(1) & 0xFF == ord('q'):
#      18         cv2.imwrite('output.jpg', img)
#
# error: OpenCV(4.2.0) /io/opencv/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
